# %% [markdown]
# #Creating The Environment

# %%
import numpy as np
import pandas as pd
import pyspark.pandas as ps
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pip install databricks-cli
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Collecting databricks-cli
#   Downloading databricks-cli-0.17.4.tar.gz (82 kB)
# Collecting click&gt;=7.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
# Collecting pyjwt&gt;=1.7.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Collecting oauthlib&gt;=3.1.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: requests&gt;=2.17.3 in /databricks/python3/lib/python3.8/site-packages (from databricks-cli) (2.25.1)
# Collecting tabulate&gt;=0.7.7
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: six&gt;=1.10.0 in /databricks/python3/lib/python3.8/site-packages (from databricks-cli) (1.15.0)
# Requirement already satisfied: urllib3&lt;1.27,&gt;=1.21.1 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.17.3-&gt;databricks-cli) (1.25.11)
# Requirement already satisfied: idna&lt;3,&gt;=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.17.3-&gt;databricks-cli) (2.10)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.17.3-&gt;databricks-cli) (2020.12.5)
# Requirement already satisfied: chardet&lt;5,&gt;=3.0.2 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.17.3-&gt;databricks-cli) (4.0.0)
# Building wheels for collected packages: databricks-cli
#   Building wheel for databricks-cli (setup.py): started
#   Building wheel for databricks-cli (setup.py): finished with status &#39;done&#39;
#   Created wheel for databricks-cli: filename=databricks_cli-0.17.4-py3-none-any.whl size=142891 sha256=30b45ef432375d89844853875725adc247272a40dcf6583bff3725f794d75f33
#   Stored in directory: /root/.cache/pip/wheels/48/7c/6e/4bf2c1748c7ecf994ca951591de81674ed6bf633e1e337d873
# Successfully built databricks-cli
# Installing collected packages: tabulate, pyjwt, oauthlib, click, databricks-cli
# Successfully installed click-8.1.3 databricks-cli-0.17.4 oauthlib-3.2.2 pyjwt-2.6.0 tabulate-0.9.0
# Python interpreter will be restarted.
# </div>

# %%
# %sh pip install networkx
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Collecting networkx
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
# Installing collected packages: networkx
# Successfully installed networkx-2.8.8
# WARNING: You are using pip version 21.0.1; however, version 22.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-91403aa3-1cba-4cc0-a5f3-dc57bde44edf/bin/python -m pip install --upgrade pip&#39; command.
# </div>

# %%
import networkx
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Reading In Files

# %%
df_02 = ps.read_parquet("dbfs:/FileStore/wifi/wifi-cleansed/2022/10/01/00/cleansedwifitraps_20221002040917.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_03 = ps.read_parquet('dbfs:/FileStore/wifi/wifi-cleansed/2022/10/02/00/cleansedwifitraps_20221003040847.parquet')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mapping = pd.read_csv('/dbfs/FileStore/wifi/station mapping/2020/03/02/17/stationextendedpaths_20200302174537.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mapping.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Node1</th><th>Node2</th><th>Split</th><th>StationNlc</th></tr></thead><tbody><tr><td>L1-02</td><td>L1-01</td><td>1.0</td><td>758</td></tr><tr><td>L1-03</td><td>L1-01</td><td>1.0</td><td>729</td></tr><tr><td>L2-04</td><td>L1-01</td><td>0.25</td><td>726</td></tr><tr><td>L2-04</td><td>L1-02</td><td>0.25</td><td>726</td></tr><tr><td>L2-04</td><td>L1-09</td><td>0.25</td><td>726</td></tr><tr><td>L2-04</td><td>L1-10</td><td>0.25</td><td>726</td></tr><tr><td>L2-02</td><td>L1-01</td><td>0.25</td><td>726</td></tr><tr><td>L2-02</td><td>L1-02</td><td>0.25</td><td>726</td></tr><tr><td>L2-02</td><td>L1-09</td><td>0.25</td><td>726</td></tr><tr><td>L2-02</td><td>L1-10</td><td>0.25</td><td>726</td></tr><tr><td>L1-04</td><td>L1-01</td><td>0.5</td><td>726</td></tr><tr><td>L1-04</td><td>L1-02</td><td>0.
1.0</td><td>556</td></tr><tr><td>L1-02</td><td>L1-01</td><td>1.0</td><td>552</td></tr><tr><td>L2-02</td><td>L1-01</td><td>1.0</td><td>552</td></tr><tr><td>L2-04</td><td>L1-01</td><td>0.25</td><td>541</td></tr><tr><td>L2-04</td><td>L1-02</td><td>0.25</td><td>541</td></tr><tr><td>L2-04</td><td>L1-03</td><td>0.25</td><td>541</td></tr><tr><td>L2-04</td><td>L1-04</td><td>0.25</td><td>541</td></tr><tr><td>L2-06</td><td>L1-01</td><td>0.25</td><td>541</td></tr><tr><td>L2-06</td><td>L1-02</td><td>0.25</td><td>541</td></tr><tr><td>L2-06</td><td>L1-03</td><td>0.25</td><td>541</td></tr><tr><td>L2-06</td><td>L1-04</td><td>0.25</td><td>541</td></tr><tr><td>L2-05</td><td>L1-01</td> ...

# %%
metadata = pd.read_csv('/dbfs/FileStore/wifi/station mapping/2019/10/25/21/stationmetadata_20191025212131.csv') #showing station name, group and Prefix
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
metadata.sort_values('StationName').display()#

Elizabeth_line = df_03.loc[(df_03.AccessPointPrefix == 'heath4', 'heath1')] 
                            #'heat5','bondst','canary','farrin', 'livpst', 'padcir', 'paddin' 'wtchpl','ealbdy','stratf','totcrt')]
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>StationName</th><th>NLC</th><th>SutorCode</th><th>Prefix</th><th>StationGroup</th><th>Dummy</th><th>CAD UPDATED</th><th>MoveCAD</th><th>CheckCAD</th><th>NetworkAndPath</th><th>AutoCorrectCAD</th><th>CADToUpload</th><th>CAD validated with Data</th><th>MatchedAPs</th><th>MissingAPa</th><th>usable</th><th>Problem files</th><th>M_Entry</th><th>M_Exit</th></tr></thead><tbody><tr><td>Acton Town</td><td>500</td><td>ACT</td><td>actotn</td><td>48</td><td>0</td><td>Y</td><td>Done</td><td>Done</td><td>Done</td><td>Done</td><td>Y</td><td>Done</td><td>9</td><td>0</td><td>Y</td><td>null</td><td>1.66497232</td><td>1.476663999</td></tr><tr><td>Aldgate</td><td>502</td><td>ALD</td><td>aldgat</td><td>26</td><td>0</td><td>Y</td><td>Done</td><td>Done</td><td>Done</td><td>Done</td><td>Y</td><td>Done</td><td>6</td><td>0</td><td>Y</td><td>null</td><td>2.120858494</td><td>2.031610038</td></tr><tr><td>Aldgate East</td><td>503</td><td>ALE</td><td>aldest</td><td>30</td><td>0</td><td>N</td><td>Done</td><td>Done</td><td>Done</td><td>Done</td><td>Y</td><td>Done</td><td>6</td><td>0</td><td>Y</td><td>null</td><td>1.861889383</td><td>1.985541496</td></tr><tr><td>Alperton</td><td>505</td><td>ALP</td><td>alprtn</td><td>75</td><td>0</td><td>N</td><td>Done</td><td>Done</td><td>Done</td><td>Done</td><td>Y</td><td>Done</td><td>9</td><td>0</td><td>Y</td><td>null</td><td>1.401842808</td><td>1.212291514</td></tr><tr><td>Amersham</td><td>506</td><td>AME</td><td>amrshm</td><td>115</td><td>0</td><td>Y</td><td>Done</td><td>Done</td><td>Done</td><td>Done</td><td>Y</td><td>Done</td><td>8</td><td>2</td><td>Y</td><td>null</td><td>1.832597532</td><td>1.727048895</td></tr><tr><td>Angel</td><td>507</td><td>ANG</td><td>angels</td><td>81</td><td>0</td><td>Y</td><td>Done</td><td>Done</td><td>Done</td><td>Done</td><td>Y</td><td>Done</td><td>11</td><td>0</td><td>Y</td><td>null</td><td>1.899970574</td><td>2.001622778</td></tr><tr><td>Archway</td><td>508</td><td>ARC</td><td>archwy</td><td>77</td><td>0</td><td>N</td><td>Done</td><td>Done</td><td>Done</td><td>Done</td><td>Y</td><td>Done</td><td>9</td><td>0</td><td>Y</td><td>null</td><td>1.714402131</td><td>1.697220714</td></tr><tr><td>Arnos Grove</td><td>509</td><td>AGR</td><td>arnosg</td><td>69</td><td>0</td><td>Y</td><td>Done</td><td>N</td><td>N</td><td>Done</td><td>N</td><td>N</td><td>10</td><td>4</td><td>N</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Arsenal</td><td>510</td><td>ARL</td><td>arsenl</td><td>70</td><td>0</td><td>N</td><td>Done</td><td>Done</td><td>Done</td><td>Done</td><td>Y</td><td>Done</td><td>10</td><td>0</td><td>Y</td><td>null</td><td>1.707883614</td><td>1.717866073</td></tr><tr><td>Baker Street</td><td>511</td><td>BST</td><td>bakstn</td><td>18</td><td>0</td><td>Y</td><td>Done</td><td>Done</td><td>Done</td><td>Done</td><td>Y</td><td>Done</td><td>45</td><td>2</td><td>Y</td><td>null</td><td>1.786581569</td><td>1.898357476</td></tr><tr><td>Balham</td><td>512</td><td>BAL</td><td>balham</td><td>85</td><td>0</td><td>Y</td><td>Done</td><td>Done</td><td>Done</td><td>Done</td><td>Y</td><td>Done</td><td>13</td><td>0</td><td>Y</td><td>null</td><td>1.884678038</td><td>1.869492501</td></tr><tr><td>Bank</td><td>513</td><td>BNK</td><td>bankst</td><td>53</td><td>0</td><td>Y</td><td>Done</td><td>Y</td><td>Y</td><td>Done</td><td>Y</td><td>Done</td><td>78</td><td>11</td><td>Y</td><td>[]</td><td>2.227228711</td><td>2.252360889</td></tr><tr><td>Barbican</td><td>501</td><td>BAR</td><td>barbic</td><td>23</td><td>0</td><td>N</td><td>Done</td><td>Done</td><td>Done</td><td>Done</td><td>Y</td><td>Done</td><td>8</td><td>0</td><td>Y</td><td>null</td><td>1.940876779</td><td>1.978052972</td></tr><tr><td>Barking</td><td>514</td><td>BKG</td><td>barkng</td><td>20</td><td>0</td><td>Y</td><td>N</td><td>N</td><td>N</td><td>N</td><td>N</td><td>N</td><td>0</td><td>0</td><td>N</td><td>null</td><td>null</td><td>null</td></tr><tr>< ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">KeyError</span>                                  Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-69302436350256&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> metadata<span class="ansi-blue-fg">.</span>sort_values<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;StationName&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>display<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-red-fg">#</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span>
# <span class="ansi-green-fg">----&gt; 3</span><span class="ansi-red-fg"> </span>Elizabeth_line <span class="ansi-blue-fg">=</span> df_03<span class="ansi-blue-fg">.</span>loc<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">(</span>df_03<span class="ansi-blue-fg">.</span>AccessPointPrefix <span class="ansi-blue-fg">==</span> <span class="ansi-blue-fg">&#39;heath4&#39;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#39;heath1&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">]</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span>                             <span class="ansi-red-fg">#&#39;heat5&#39;,&#39;bondst&#39;,&#39;canary&#39;,&#39;farrin&#39;, &#39;livpst&#39;, &#39;padcir&#39;, &#39;paddin&#39; &#39;wtchpl&#39;,&#39;ealbdy&#39;,&#39;stratf&#39;,&#39;totcrt&#39;)]</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/pandas/indexing.py</span> in <span class="ansi-cyan-fg">__getitem__</span><span class="ansi-blue-fg">(self, key)</span>
# <span class="ansi-green-intense-fg ansi-bold">    478</span>                 returns_series<span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">    479</span>                 series_name<span class="ansi-blue-fg">,</span>
# <span class="ansi-green-fg">--&gt; 480</span><span class="ansi-red-fg">             ) = self._select_cols(cols_sel)
# </span><span class="ansi-green-intense-fg ansi-bold">    481</span>
# <span class="ansi-green-intense-fg ansi-bold">    482</span>             <span class="ansi-green-fg">if</span> cond <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">None</span> <span class="ansi-green-fg">and</span> limit <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">None</span> <span class="ansi-green-fg">and</span> returns_series<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/pandas/indexing.py</span> in <span class="ansi-cyan-fg">_select_cols</span><span class="ansi-blue-fg">(self, cols_sel, missing_keys)</span>
# <span class="ansi-green-intense-fg ansi-bold">    325</span>             <span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>_select_cols_by_iterable<span class="ansi-blue-fg">(</span>cols_sel<span class="ansi-blue-fg">,</span> missing_keys<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    326</span>         <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">--&gt; 327</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>_select_cols_else<span class="ansi-blue-fg">(</span>cols_sel<span class="ansi-blue-fg">,</span> missing_keys<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    328</span>
# <span class="ansi-green-intense-fg ansi-bold">    329</span>     <span class="ansi-red-fg"># Methods for row selection</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/pandas/indexing.py</span> in <span class="ansi-cyan-fg">_select_cols_else</span><span class="ansi-blue-fg">(self, cols_sel, missing_keys)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1371</span>         <span class="ansi-green-fg">if</span> <span class="ansi-green-fg">not</span> is_name_like_tuple<span class="ansi-blue-fg">(</span>cols_sel<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   1372</span>             cols_sel <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">(</span>cols_sel<span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 1373</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>_get_from_multiindex_column<span class="ansi-blue-fg">(</span>cols_sel<span class="ansi-blue-fg">,</span> missing_keys<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1374</span>
# <span class="ansi-green-intense-fg ansi-bold">   1375</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/pandas/indexing.py</span> in <span class="ansi-cyan-fg">_get_from_multiindex_column</span><span class="ansi-blue-fg">(self, key, missing_keys, labels, recursed)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1189</span>             <span class="ansi-green-fg">if</span> len<span class="ansi-blue-fg">(</span>labels<span class="ansi-blue-fg">)</span> <span class="ansi-blue-fg">==</span> <span class="ansi-cyan-fg">0</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   1190</span>                 <span class="ansi-green-fg">if</span> missing_keys <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">-&gt; 1191</span><span class="ansi-red-fg">                     </span><span class="ansi-green-fg">raise</span> KeyError<span class="ansi-blue-fg">(</span>k<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1192</span>                 <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   1193</span>                     missing_keys<span class="ansi-blue-fg">.</span>append<span class="ansi-blue-fg">(</span>key<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">KeyError</span>: &#39;heath1&#39;</div>

# %%
df_03['CaptureTimeLocal'] = df_03['CaptureTimeLocal'].astype('datetime64[ns]')
df_03.sort_values("CaptureTime").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SequenceNumber</th><th>Offset</th><th>EnqueuedTimeUtc</th><th>EnqueuedTimeLocal</th><th>Oid</th><th>Timestamp</th><th>CaptureTime</th><th>CaptureTimeLocal</th><th>Sender</th><th>ClientMacAddress</th><th>AccessPointName</th><th>AccessPointMacAddress</th><th>AccessPointPrefix</th><th>TravelDay</th><th>ProcessedTimeLocal</th><th>OidDescription</th><th>TimeBucket</th></tr></thead><tbody><tr><td>34416731362</td><td>3633477908150400</td><td>10/2/2022 12:00:26 AM</td><td>2022-10-02 01:00:26</td><td>1.3.6.1.4.1.14179.2.6.3.53</td><td>138308100</td><td>638002656262423819</td><td>2022-10-02T01:00:26.242+0000</td><td>10.87.35.11:32768:wifivm000004</td><td>fP1gcoeD17RrBf0Rcb5/mgv39vl1Eegh1X9+aPUrGbI=</td><td>stockw-wap16</td><td>C8F9F92A7750</td><td>stockw</td><td>2022-10-02</td><td>2022-10-03 05:11:17.782131</td><td>bsnDot11StationAssociate</td><td>AM0</td></tr><tr><td>34416731367</td><td>3633477908154672</td><td>10/2/2022 12:00:26 AM</td><td>2022-10-02 01:00:26</td><td>1.3.6.1.4.1.14179.2.6.3.1</td><td>129352200</td><td>638002656263205394</td><td>2022-10-02T01:00:26.320+0000</td><td>10.87.35.6:32768:wifivm000004</td><td>rjzrFHnOMTDuER4YP/EiBIVD08dbnfVo/5FWCXECi0U=</td><td>oxfcir-wap42</td><td>64A0E7FF1C30</td><td>oxfcir</td><td>2022-10-02</td><td>2022-10-03 05:11:17.782131</td><td>bsnDot11St

# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SequenceNumber</th><th>Offset</th><th>EnqueuedTimeUtc</th><th>EnqueuedTimeLocal</th><th>Oid</th><th>Timestamp</th><th>CaptureTime</th><th>CaptureTimeLocal</th><th>Sender</th><th>ClientMacAddress</th><th>AccessPointName</th><th>AccessPointMacAddress</th><th>AccessPointPrefix</th><th>TravelDay</th><th>ProcessedTimeLocal</th><th>OidDescription</th><th>TimeBucket</th></tr></thead><tbody></tbody></table></div>

# %%
Elizabeth_line = df.loc[(df.AccessPointPrefix == 'knight')].count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-69302436350258&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>Elizabeth_line <span class="ansi-blue-fg">=</span> df<span class="ansi-blue-fg">.</span>loc<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">(</span>df<span class="ansi-blue-fg">.</span>AccessPointPrefix <span class="ansi-blue-fg">==</span> <span class="ansi-blue-fg">&#39;knight&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">.</span>count<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;df&#39; is not defined</div>

# %%
g_address.sort_values(['CaptureTimeLocal']).display()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-813333961224228&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>g_address<span class="ansi-blue-fg">.</span>sort_values<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;CaptureTimeLocal&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>display<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;g_address&#39; is not defined</div>

# %%
x = df_03['ClientMacAddress'].unique().sum
print(x)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
bond_street = df.loc[(df.AccessPointPrefix == "bondst") & (df.TravelDay == '2022-10-01')]
bond_street.display()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
bond_street[['AccessPointPrefix']].count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
bond_street.sort_values(['ProcessedTimeLocal']).display()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df.sort_values(["TravelDay"]).display()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df['CaptureTimeLocal'] = df['CaptureTimeLocal'].astype('datetime64[ns]')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df['TravelDay'] = df['TravelDay'].astype('datetime64[ns]')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df.display()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df2 = ps.read_parquet ('dbfs:/FileStore/wifi/wifi-curated/2022/10/02/00/stationrouting_20221003061545.parquet/part_00001_tid_1051565670487661852_4a32311b_ad1b_4a40_9777_a5489897d124_4251_1_c000_snappy.parquet')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df2.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ClientMacAddress</th><th>JourneyIndex</th><th>MovementIndex</th><th>FirstTrapTime</th><th>LastTrapTime</th><th>SeenPath</th><th>ShortestSeenRoute</th><th>ShortestCompleteRoute</th><th>IncompletePathIndicator</th><th>TrapNlc</th><th>Platforms</th><th>MovementIndicator</th></tr></thead><tbody><tr><td>XX6o6lCskPcZEtuBI3IHm+FWMOEwHEkS01mdDpNXXNo=</td><td>3</td><td>5</td><td>2022-10-02T04:03:33.133+0000</td><td>2022-10-02T04:09:34.992+0000</td><td>[actotn-wap07, actotn-wap04, actotn-wap01]</td><td>L2-04\L2-05\L1-07</td><td>L2-04\L1-15\L1-14\L1-11\L1-08\L1-07</td><td>2</td><td>500</td><td>null</td><td>null</td></tr><tr><td>3W81L0N3JDgDcWVxHvbDTe0MKKUdTJGcIf5ip3R2QXQ=</td><td>1</td><td>2</td><td>2022-10-02T13:11:09.309+0000</td><td>2022-10-02T13:11:36.860+0000</td><td>[actotn-wap03, actotn-wap06, actotn-wap04, actotn-wap05]</td><td>L2-02\L2-09</td><td>L2-02\L2-05\L2-06\L2-09</td><td>0</td><td>500</td><td>null</td><td>null</td></tr><tr><td>tHoVhfBZNhHKvGM9GaYaseVBld+k9wLz5V1KfNT0KSg=</td><td>1</td><td>1</td><td>2022-10-02T11:51:13.041+0000</td><td>2022-10-02T11:51:42.019+0000</td><td>[actotn-wap03, actotn-wap06, actotn-wap04, actotn-wap05]</td><td>L2-02\L2-09</td><td>L2-02\L2-05\L2-06\L2-09</td><td>0</td><td>500</td><td>List(3)</td><td>Entry</td></tr><tr><td>imJTiaXV7njoxkLE6kyNAcU9I1VxMu2JWwKHeJR1s9c=</td><td>2</td><td>3</td><td>2022-10-02T13:24:14.111+0000</td><td>2022-10-02T13:25:21.783+0000</td><td>[actotn-wap07, actotn-wap03, actotn-wap02, actotn-wap01]</td><td>L2-04\L2-01\L1-07</td><td>L2-04\L2-01\L1-10\L1-08\L1-07</td><td>2</td><td>500</td><td>null</td><td>null</td></tr><tr><td>5cAzFJVhXWUg+WcaZXyZ1kqKTQNr9LlA5KwjSwo9Axk=</td><td>1</td><td>8</td><td>2022-10-02T14:21:57.813+0000</td><td>2022-10-02T14:24:21.346+0000</td><td>[actotn-wap07, actotn-wap03, actotn-wap02, actotn-wap01]</td><td>L2-04\L2-01\L1-07</td><td>L2-04\L2-01\L1-10\L1-08\L1-07</td><td>2</td><td>500</td><td>null</td><td>null</td></tr><tr><td>na2CF9KuZwv3HAqqvc8esyufrbcALxVrSv0oYaCNLwA=</td><td>1</td><td>8</td><td>2022-10-02T22:23:31.073+0000</td><td>2022-10-02T22:25:40.234+0000</td><td>[actotn-wap07, actotn-wap03, actotn-wap02, actotn-wap01]</td><td>L2-04\L2-01\L1-07</td><td>L2-04\L2-01\L1-10\L1-08\L1-07</td><td>2</td><td>500</td><td>null</td><td>null</td></tr><tr><td>xRFPBPJaAQp/VD+HC3m8D9D1hnhLx4YdWgi1FxQ43Co=</td><td>1</td><td>3</td><td>2022-10-02T20:35:01.909+0000</td><td>2022-10-02T20:36:10.295+0000</td><td>[actotn-wap07, actotn-wap03, actotn-wap02, actotn-wap01]</td><td>L2-04\L2-01\L1-07</td><td>L2-04\L2-01\L1-10\L1-08\L1-07</td><td>2</td><td>500</td><td>null</td><td>null</td></tr><tr><td>ZVzeIukNbaTbjoRsUl8AvyHfzAtKVrBS3OY2Wgua0sM=</td><td>2</td><td>12</td><td>2022-10-02T22:39:02.635+0000</td><td>2022-10-02T22:40:05.652+0000</td><td>[actotn-wap07, actotn-wap03, actotn-wap02, actotn-wap01]</td><td>L2-04\L2-01\L1-07</td><td>L2-04\L2-01\L1-10\L1-08\L1-07</td><td>2</td><td>500</td><td>null</td><td>null</td></tr><tr><td>npDuFiHsiFKcmclHFRzlYbs6saOWfDWMOl/uWK3dhdY=</td><td>1</td><td>5</td><td>2022-10-02T21:27:52.752+0000</td><td>2022-10-02T21:28:50.216+0000</td><td>[actotn-wap07, actotn-wap03, actotn-wap02, actotn-wap01]</td><td>L2-04\L2-01\L1-07</td><td>L2-04\L2-01\L1-10\L1-08\L1-07</td><td>2</td><td>500</td><td>null</td><td>null</td></tr><tr><td>scpUolqrT4nSZ/e2mLl+d3bfmVZPChCi6i14Uh3CERg=</td><td>2</td><td>12</td><td>2022-10-02T14:16:28.954+0000</td><td>2022-10-02T14:17:25.115+0000</td><td>[actotn-wap07, actotn-wap03, actotn-wap02, actotn-wap01]</td><td>L2-04\L2-01\L1-07</td><td>L2-04\L2-01\L1-10\L1-08\L1-07</td><td>2</td><td>500</td><td>null</td><td>null</td></tr><tr><td>CefXa6AW85SXMOCEp52woQajxzhstGGoZGi4McqvKiE=</td><td>1</td><td>11</td><td>2022-10-02T22:59:09.412+0000</td><td>2022-10-02T23:00:10.800+0000</td><td>[actotn-wap07, actotn-wap03, actotn-wap02, actotn-wap01]</td><td>L2-04\L2-01\L1-07</td><td>L2-04\L2-01\L1-10\L1-08\L1-07</td><td> ...

# %%
df2['ClientMacAddress'].max()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
mac_address = df2.loc[(df2.ClientMacAddress == "zzneBJuF2Sq44WPKsQESjuvo1U0RADwIb04ppfek3OY=")]
#g_address = df.loc[(df.ClientMacAddress == "Gary3qZD5s9ZcrWqPz7mFwN2Q+ySNB+LiaUa6u0tBLU=")]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
 df3 = mac_address.groupby('SeenPath').max()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df3
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df2.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pyspark.pandas.frame.DataFrame&#39;&gt;
# Int64Index: 5320 entries, 0 to 5319
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ClientMacAddress         5320 non-null   object
#  1   JourneyIndex             5320 non-null   int64
#  2   MovementIndex            5320 non-null   int64
#  3   FirstTrapTime            5320 non-null   datetime64[ns]
#  4   LastTrapTime             5320 non-null   datetime64[ns]
#  5   SeenPath                 5320 non-null   object
#  6   ShortestSeenRoute        5320 non-null   object
#  7   ShortestCompleteRoute    5320 non-null   object
#  8   IncompletePathIndicator  5320 non-null   int32
#  9   TrapNlc                  5320 non-null   object
#  10  Platforms                2730 non-null   object
#  11  MovementIndicator        2730 non-null   object
# dtypes: datetime64[ns](2), int32(1), int64(2), object(7)</div>
